# %% [markdown]
# I am using Superstore date present [here](https://community.tableau.com/s/question/0D54T00000CWeX8SAL/sample-superstore-sales-excelxls)

# %%
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
import matplotlib
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %% [markdown]
# # Doubt

# %%
df = pd.read_csv("Superstore.csv")
df
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xf6 in position 9: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-40-2a3577cd3041> in <module>
# ----> 1 df = pd.read_csv("Superstore.csv")
#       2 df
#
# ...

# %% [markdown]
# ## Changed Encoding

# %%
df = pd.read_csv("Superstore.csv", encoding = "ISO-8859-1")
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 1          2  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 2          3  CA-2016-138688  12-06-2016  16-06-2016    Second Class
# 3          4  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 4          5  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422  21-01-2014  23-01-2014    Second Class
# 9990    9991  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9991    9992  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9992    9993  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
# 9993    9994  CA-2017-119914  04-05-2017  09-05-2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# Only choosing category "Furniture"

# %%
furniture = df.loc[df['Category'] == 'Furniture']
furniture
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 1          2  CA-2016-152156  08-11-2016  11-11-2016    Second Class
# 3          4  US-2015-108966  11-10-2015  18-10-2015  Standard Class
# 5          6  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 10        11  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# ...      ...             ...         ...         ...             ...
# 9962    9963  CA-2015-168088  19-03-2015  22-03-2015     First Class
# 9964    9965  CA-2016-146374  05-12-2016  10-12-2016    Second Class
# 9980    9981  US-2015-151435  06-09-2015  09-09-2015    Second Class
# 9989    9990  CA-2014-110422  21-01-2014  23-01-2014    Second Class
# 9990    9991  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
#
#      Customer ID     Customer Name      Segment        Country  \
# 0       CG-12520       Claire Gute     Consumer  United States
# ...

# %% [markdown]
# Find the range of dates

# %%
furniture['Order Date'].min(), furniture['Order Date'].max()
# Out:
# ('01-01-2017', '31-12-2015')

# %%
cols = ['Row ID', 'Order ID', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Quantity', 'Discount', 'Profit']
furniture.drop(cols, axis=1, inplace=True)
furniture = furniture.sort_values('Order Date')
furniture.isnull().sum()
# Out:
# Order Date    0
# Sales         0
# dtype: int64

# %% [markdown]
# Removing extra columns

# %%
furniture
# Out:
#       Order Date     Sales
# 4009  01-01-2017   474.430
# 8071  01-01-2017   310.744
# 848   01-01-2017    48.896
# 8070  01-01-2017   141.420
# 8310  01-03-2014   376.509
# ...          ...       ...
# 7680  31-12-2014   341.960
# 7681  31-12-2014   605.880
# 1545  31-12-2014  1573.488
# 2341  31-12-2014    63.200
# 2136  31-12-2015    14.760
#
# [2121 rows x 2 columns]

# %% [markdown]
# Clubbing all the sales that happened on the same date

# %%
furniture = furniture.groupby('Order Date')['Sales'].sum().reset_index()

# %% [markdown]
# Setting "Order Date" as index

# %%
furniture = furniture.set_index('Order Date')
furniture.index
# Out:
# Index(['01-01-2017', '01-03-2014', '01-03-2015', '01-03-2016', '01-04-2016',
#        '01-04-2017', '01-05-2015', '01-05-2016', '01-05-2017', '01-06-2014',
#        ...
#        '31-07-2015', '31-07-2016', '31-07-2017', '31-08-2015', '31-08-2017',
#        '31-10-2014', '31-10-2015', '31-10-2016', '31-12-2014', '31-12-2015'],
#       dtype='object', name='Order Date', length=889)

# %%
furniture.plot(figsize=(15, 6))
plt.show()

# %% [markdown]
# Repeating the same process for category "Technology"

# %%
technology = df.loc[df['Category'] == 'Technology']
technology
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 7          8  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 11        12  CA-2014-115812  09-06-2014  14-06-2014  Standard Class
# 19        20  CA-2014-143336  27-08-2014  01-09-2014    Second Class
# 26        27  CA-2016-121755  16-01-2016  20-01-2016    Second Class
# 35        36  CA-2016-117590  08-12-2016  10-12-2016     First Class
# ...      ...             ...         ...         ...             ...
# 9983    9984  US-2016-157728  22-09-2016  28-09-2016  Standard Class
# 9986    9987  CA-2016-125794  29-09-2016  03-10-2016  Standard Class
# 9987    9988  CA-2017-163629  17-11-2017  21-11-2017  Standard Class
# 9988    9989  CA-2017-163629  17-11-2017  21-11-2017  Standard Class
# 9991    9992  CA-2017-121258  26-02-2017  03-03-2017  Standard Class
#
#      Customer ID       Customer Name    Segment        Country           City  \
# ...

# %%
cols = ['Row ID', 'Order ID', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Quantity', 'Discount', 'Profit']
technology.drop(cols, axis=1, inplace=True)
technology = technology.sort_values('Order Date')
technology.isnull().sum()
# Out:
# Order Date    0
# Sales         0
# dtype: int64

# %%
technology = technology.groupby('Order Date')['Sales'].sum().reset_index()

# %%
technology = technology.set_index('Order Date')
technology.index
# Out:
# Index(['01-02-2014', '01-03-2014', '01-03-2015', '01-03-2016', '01-04-2016',
#        '01-04-2017', '01-05-2015', '01-05-2017', '01-06-2014', '01-06-2015',
#        ...
#        '31-07-2016', '31-07-2017', '31-08-2014', '31-08-2015', '31-08-2017',
#        '31-10-2014', '31-10-2015', '31-10-2017', '31-12-2014', '31-12-2016'],
#       dtype='object', name='Order Date', length=824)

# %%
technology.plot(figsize=(10, 4))
plt.ylabel('Technology')
plt.show()
furniture.plot(figsize=(10, 4))
plt.ylabel('Furniture')
plt.show()
